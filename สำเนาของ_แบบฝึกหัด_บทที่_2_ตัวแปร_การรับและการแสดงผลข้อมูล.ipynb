# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonSKennedy2007/Computer-Programming-for-Mathematics-1/blob/main/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_%E0%B9%81%E0%B8%9A%E0%B8%9A%E0%B8%9D%E0%B8%B6%E0%B8%81%E0%B8%AB%E0%B8%B1%E0%B8%94_%E0%B8%9A%E0%B8%97%E0%B8%97%E0%B8%B5%E0%B9%88_2_%E0%B8%95%E0%B8%B1%E0%B8%A7%E0%B9%81%E0%B8%9B%E0%B8%A3_%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%A3%E0%B8%B1%E0%B8%9A%E0%B9%81%E0%B8%A5%E0%B8%B0%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B9%81%E0%B8%AA%E0%B8%94%E0%B8%87%E0%B8%9C%E0%B8%A5%E0%B8%82%E0%B9%89%E0%B8%AD%E0%B8%A1%E0%B8%B9%E0%B8%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 040223101 การเขียนโปรแกรมคอมพิวเตอร์สำหรับคณิตศาสตร์ 1
# ## (Computer Programming for Mathematics 1)
#
# # แบบฝึกหัด บทที่ 2: ตัวแปร การรับและการแสดงผลข้อมูล
# ### Variables, Input and Output
#
# **ผู้สอน:** รศ.ดร.อนุชิต จิตพัฒนกุล
# ภาควิชาคณิตศาสตร์ คณะวิทยาศาสตร์ประยุกต์  มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ
#
# ---
#
# ### 📝 คำชี้แจง
# - ให้นักศึกษาเขียนโปรแกรมภาษา Python แก้โจทย์แต่ละข้อในเซลล์โค้ดที่เว้นว่างไว้ใต้โจทย์
# - กดปุ่ม **▶ Run** (หรือ Shift+Enter) เพื่อรันโค้ดและตรวจผลลัพธ์
# - โจทย์แบ่งเป็น 3 ระดับจากง่ายไปยาก ควรทำไล่ตามลำดับ
# - เขียนชื่อ-รหัสนักศึกษาของคุณในเซลล์ด้านล่างก่อนเริ่มทำ

# %%
# ✏️ กรอกข้อมูลของคุณ
student_name = ""   # ชื่อ-นามสกุล
student_id = ""     # รหัสนักศึกษา
print("ผู้ทำแบบฝึกหัด:", student_name, student_id)

# %% [markdown]
# ### 🔧 ระบบตรวจคำตอบ
# รันเซลล์ด้านล่าง **หนึ่งครั้ง** ก่อนเริ่มทำ จากนั้นเมื่อทำข้อใดเสร็จ ให้รันเซลล์ `ตรวจ(เลขข้อ)` ที่อยู่ใต้ข้อนั้น เพื่อตรวจว่าคำตอบถูกหรือยัง

# %%
# 🔧 ระบบตรวจคำตอบอัตโนมัติ — รันเซลล์นี้ "หนึ่งครั้ง" ก่อนเริ่มทำแบบฝึกหัด
# วิธีใช้: เขียนคำตอบในเซลล์ของแต่ละข้อ กด ▶ รันให้เห็นผลลัพธ์ก่อน
#         จากนั้นรันเซลล์  ตรวจ(เลขข้อ)  ที่อยู่ใต้ข้อนั้น เพื่อตรวจว่าถูกไหม
import io, re, contextlib, json as _json

_KEY = _json.loads(r"""{"1": {"text": ["ปิติ"]}, "2": {"num": [29]}, "3": {"text": ["float"]}, "4": {"text": ["สวัสดีคุณ", "มานี"]}, "5": {"num": [20]}, "6": {"num": [9]}, "7": {"num": [50]}, "8": {"num": [21]}, "9": {"num": [1, 2, 3]}, "10": {"num": [10]}, "11": {"num": [8]}, "12": {"num": [360]}, "13": {"num": [150]}, "14": {"num": [78.53975], "tol": 0.05}, "15": {"text": ["สมชาย", "ใจดี"]}, "16": {"text": ["คะแนนของคุณคือ"], "num": [85]}, "17": {"text": ["str"]}, "18": {"num": [25.0]}, "19": {"text": ["อุณหภูมิ", "องศา"], "num": [30]}, "20": {"num": [20]}, "21": {"num": [16, 8, 48, 3]}, "22": {"num": [43.98226, 153.93791], "tol": 0.05}, "23": {"num": [11, 1]}, "24": {"num": [86.0]}, "25": {"num": [245, 81.67], "tol": 0.05}, "26": {"num": [100.0]}, "27": {"num": [40, 26]}, "28": {"num": [13]}, "29": {"num": [20.76], "tol": 0.05}, "30": {"num": [8, 3]}, "31": {"num": [400]}, "32": {"num": [3, 20]}, "33": {"num": [36, 216]}, "34": {"num": [21.5]}, "35": {"num": [1605.0]}, "36": {"num": [3, 20]}, "37": {"num": [5]}, "38": {"num": [60.0]}, "39": {"num": [4231]}, "40": {"num": [24]}, "41": {"num": [15]}, "42": {"num": [2000.0]}, "43": {"num": [5.0], "tol": 0.05}, "44": {"num": [12, 50]}, "45": {"num": [100.0], "tol": 0.05}, "46": {"num": [5.0], "tol": 0.05}, "47": {"num": [157]}, "48": {"num": [25.0], "tol": 0.05}, "49": {"num": [1, 2, 5]}, "50": {"num": [1500.0]}}""")
_KEY = {int(k): v for k, v in _KEY.items()}

def _หาโค้ด(qno):
    marker = "เขียนโค้ดข้อ %d ที่นี่" % qno
    hist = _ih[:-1]                       # ไม่รวมเซลล์ตรวจที่กำลังรันอยู่
    for src in reversed(hist):
        if marker in src:
            return src
    return hist[-1] if hist else None     # สำรอง: เซลล์ที่รันก่อนหน้า

def _ไม่มีโค้ด(code):
    if not code:
        return True
    body = "\n".join(l for l in code.splitlines() if not l.strip().startswith("#"))
    return body.strip() == ""

def _ตัวเลข(s):
    return [float(x) for x in re.findall(r"-?\d+\.?\d*", s)]

def _นอร์ม(s):
    return s.replace(" ", "").replace("\t", "").replace("\n", "").lower()

def ตรวจ(qno):
    item = _KEY.get(qno)
    if item is None:
        print("ยังไม่มีเฉลยของข้อ", qno); return
    code = _หาโค้ด(qno)
    if _ไม่มีโค้ด(code):
        print("⚠️  ข้อ %d: ยังไม่พบโค้ดคำตอบ — กรุณารันเซลล์คำตอบของข้อนี้ก่อน แล้วค่อยรันเซลล์ตรวจอีกครั้ง" % qno)
        return
    try:
        buf = io.StringIO()
        with contextlib.redirect_stdout(buf):
            exec(compile(code, "<คำตอบข้อ %d>" % qno, "exec"), {})
        out = buf.getvalue()
    except Exception as e:
        print("❌  ข้อ %d: โค้ดรันแล้วเกิดข้อผิดพลาด → %s: %s" % (qno, type(e).__name__, e))
        return

    if item.get("manual"):
        if out.strip():
            print("ℹ️  ข้อ %d: ข้อนี้ขึ้นกับข้อมูลของนักศึกษา ระบบตรวจอัตโนมัติให้ไม่ได้" % qno)
            print("    โปรแกรมของคุณแสดงผลว่า:")
            for line in out.rstrip().splitlines():
                print("      ", line)
            print("    ✔️  ถ้าผลตรงกับที่โจทย์ต้องการ ถือว่าผ่าน")
        else:
            print("⚠️  ข้อ %d: ยังไม่มีผลลัพธ์แสดงออกมา ลองตรวจว่าใช้ print() แล้วหรือยัง" % qno)
        return

    problems = []
    if "text" in item:
        n = _นอร์ม(out)
        for t in item["text"]:
            if _นอร์ม(t) not in n:
                problems.append("ต้องมีข้อความ: %s" % t)
    if "num" in item:
        nums = _ตัวเลข(out)
        tol = item.get("tol")
        for v in item["num"]:
            ok = any(abs(v - x) <= (tol if tol is not None else max(1e-6, abs(v) * 1e-4)) for x in nums)
            if not ok:
                problems.append("ต้องมีค่า: %s" % (("%g" % v)))

    if not problems:
        print("✅  ข้อ %d: ถูกต้อง! เก่งมาก 🎉" % qno)
    else:
        print("❌  ข้อ %d: ยังไม่ถูก" % qno)
        for p in problems:
            print("     • " + p)
        shown = out.strip() if out.strip() else "(ไม่มีผลลัพธ์ — ใช้ print() หรือยัง?)"
        print("     ผลลัพธ์ที่โปรแกรมของคุณแสดง: %s" % shown)

print("✅ พร้อมตรวจคำตอบแล้ว — ทำข้อไหนเสร็จ ให้รันเซลล์  ตรวจ(เลขข้อ)  ใต้ข้อนั้นได้เลย")
# Out:
# ✅ พร้อมตรวจคำตอบแล้ว — ทำข้อไหนเสร็จ ให้รันเซลล์  ตรวจ(เลขข้อ)  ใต้ข้อนั้นได้เลย

# %% [markdown]
# ---
# ## ระดับที่ 1 — พื้นฐาน (Basic)
# _ฝึกใช้คำสั่งและไวยากรณ์พื้นฐานของบทนี้ให้คล่อง_

# %% [markdown]
# **ข้อ 1.** กำหนดตัวแปร `name = "ปิติ"` แล้วแสดงค่าตัวแปร `name` ออกทางหน้าจอ

# %%
# ✍️ เขียนโค้ดข้อ 1 ที่นี่
name = "ปิติ"
print(name)
# Out:
# ปิติ

# %%
# ✅ ตรวจคำตอบข้อ 1 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(1)
# Out:
# ✅  ข้อ 1: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 2.** กำหนดตัวแปร `x = 25` และ `y = 4` แล้วแสดงผลบวกของทั้งสอง

# %%
x = 25
y = 4
print(x+y)
# Out:
# 29

# %%
# ✅ ตรวจคำตอบข้อ 2 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(2)
# Out:
# ✅  ข้อ 2: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 3.** กำหนดตัวแปร `pi = 3.14159` แล้วแสดงชนิดข้อมูลของ `pi` ด้วยฟังก์ชัน `type()`

# %%
pi = 3.14159
print(type(pi))
# Out:
# <class 'float'>

# %%
# ✅ ตรวจคำตอบข้อ 3 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(3)
# Out:
# ✅  ข้อ 3: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 4.** กำหนดตัวแปร `name = "มานี"` แล้วแสดงข้อความ `สวัสดีคุณ มานี` ด้วย f-string

# %%
# ✍️ เขียนโค้ดข้อ 4 ที่นี่
name = "มานี"
print(f"สวัสดีคุณ{name}")
# Out:
# สวัสดีคุณมานี

# %%
# ✅ ตรวจคำตอบข้อ 4 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(4)
# Out:
# ✅  ข้อ 4: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 5.** กำหนดอายุด้วยการแปลงข้อความ `"20"` เป็นจำนวนเต็มด้วย `int()` แล้วแสดงค่าอายุ

# %%
age = "20"
print(int(age))
# Out:
# 20

# %%
# ✅ ตรวจคำตอบข้อ 5 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(5)
# Out:
# ✅  ข้อ 5: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 6.** แปลงเลขทศนิยม `9.99` เป็นจำนวนเต็มด้วย `int()` แล้วแสดงผล

# %%
num = 9.99
print(int(num))
# Out:
# 9

# %%
# ✅ ตรวจคำตอบข้อ 6 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(6)
# Out:
# ✅  ข้อ 6: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 7.** แปลงจำนวนเต็ม `50` เป็นทศนิยมด้วย `float()` แล้วแสดงผล

# %%
# ✍️ เขียนโค้ดข้อ 7 ที่นี่
num = 50
print(float(num))
# Out:
# 50.0

# %%
# ✅ ตรวจคำตอบข้อ 7 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(7)
# Out:
# ✅  ข้อ 7: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 8.** กำหนด `a = 7`, `b = 3` แล้วแสดงผลคูณของทั้งสองด้วย f-string

# %%
a,b = 7,3
print(f"ผลคูณของ 7 และ 3 เท่ากับ {a*b}")
# Out:
# ผลคูณของ 7 และ 3 เท่ากับ 21

# %%
# ✅ ตรวจคำตอบข้อ 8 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(8)
# Out:
# ✅  ข้อ 8: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 9.** กำหนดตัวแปรสามตัว `x, y, z` ให้มีค่า `1, 2, 3` พร้อมกันในบรรทัดเดียว แล้วแสดงทั้งสามค่า

# %%
x,y,z = 1,2,3
print(x,y,z)
# Out:
# 1 2 3

# %%
# ✅ ตรวจคำตอบข้อ 9 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(9)
# Out:
# ✅  ข้อ 9: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 10.** กำหนด `a = b = 10` แล้วแสดงค่าทั้งสองตัวแปร

# %%
a = b = 10
print(a,b)
# Out:
# 10 10

# %%
# ✅ ตรวจคำตอบข้อ 10 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(10)
# Out:
# ✅  ข้อ 10: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 11.** กำหนด `n = 7` แล้วแสดงค่าที่มากกว่าเดิม 1

# %%
# ✍️ เขียนโค้ดข้อ 11 ที่นี่
n = 7
print(n+1)
# Out:
# 8

# %%
# ✅ ตรวจคำตอบข้อ 11 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(11)
# Out:
# ✅  ข้อ 11: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 12.** กำหนดราคาสินค้า `price = 120` และจำนวน `qty = 3` แล้วแสดงราคารวม

# %%
# ✍️ เขียนโค้ดข้อ 12 ที่นี่
price = 120
qty = 3
print(price*qty)
# Out:
# 360

# %%
# ✅ ตรวจคำตอบข้อ 12 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(12)
# Out:
# ✅  ข้อ 12: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 13.** แปลงข้อความ `"100"` เป็นจำนวนเต็ม แล้วบวกด้วย 50 และแสดงผล

# %%
# ✍️ เขียนโค้ดข้อ 13 ที่นี่
num1 = "100"
print(int(num1) + 50)
# Out:
# 150

# %%
# ✅ ตรวจคำตอบข้อ 13 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(13)
# Out:
# ✅  ข้อ 13: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 14.** กำหนด `r = 5` แล้วแสดงพื้นที่วงกลม (ใช้ค่า 3.14159) ด้วย f-string

# %%
# ✍️ เขียนโค้ดข้อ 14 ที่นี่
r = 5
pi = 3.14159
print(f"พื้นที่วงกลม {r**2 * pi}")
# Out:
# พื้นที่วงกลม 78.53975

# %%
# ✅ ตรวจคำตอบข้อ 14 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(14)
# Out:
# ✅  ข้อ 14: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 15.** กำหนด `first = "สมชาย"` และ `last = "ใจดี"` แล้วแสดงต่อกันเป็นชื่อเต็ม

# %%
# ✍️ เขียนโค้ดข้อ 15 ที่นี่
first = "สมชาย"
last = "ใจดี"
print(first,last)
# Out:
# สมชาย ใจดี

# %%
# ✅ ตรวจคำตอบข้อ 15 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(15)
# Out:
# ✅  ข้อ 15: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 16.** กำหนด `score = 85` แล้วแสดงข้อความ `คะแนนของคุณคือ 85` ด้วย f-string

# %%
# ✍️ เขียนโค้ดข้อ 16 ที่นี่
score = 85
print(f"คะแนนของคุณคือ {score}")
# Out:
# คะแนนของคุณคือ 85

# %%
# ✅ ตรวจคำตอบข้อ 16 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(16)
# Out:
# ✅  ข้อ 16: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 17.** แปลงจำนวนเต็ม `7` เป็นข้อความด้วย `str()` แล้วแสดงชนิดข้อมูลของผลลัพธ์

# %%
# ✍️ เขียนโค้ดข้อ 17 ที่นี่
num = str(7)
print(type(num))
# Out:
# <class 'str'>

# %%
# ✅ ตรวจคำตอบข้อ 17 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(17)
# Out:
# ✅  ข้อ 17: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 18.** กำหนด `x = 12.5` แล้วแสดงค่าสองเท่าของเลขนั้น

# %%
# ✍️ เขียนโค้ดข้อ 18 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 18 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(18)

# %% [markdown]
# **ข้อ 19.** กำหนด `temp = 30` แล้วแสดงข้อความ `อุณหภูมิ 30 องศา` ด้วย f-string

# %%
# ✍️ เขียนโค้ดข้อ 19 ที่นี่
temp = 30
print(f"อุณหภูมิ {temp} องศา")
# Out:
# อุณหภูมิ 30 องศา

# %%
# ✅ ตรวจคำตอบข้อ 19 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(19)
# Out:
# ✅  ข้อ 19: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# **ข้อ 20.** กำหนด `a = 10` แล้วเปลี่ยนค่า `a` เป็น 20 จากนั้นแสดงค่า `a`

# %%
# ✍️ เขียนโค้ดข้อ 20 ที่นี่
a = 10
a = 20
print(a)
# Out:
# 20

# %%
# ✅ ตรวจคำตอบข้อ 20 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(20)
# Out:
# ✅  ข้อ 20: ถูกต้อง! เก่งมาก 🎉

# %% [markdown]
# ---
# ## ระดับที่ 2 — ปานกลาง (Intermediate)
# _ประยุกต์ความรู้แก้โจทย์ที่ซับซ้อนขึ้นและผสมหลายแนวคิด_

# %% [markdown]
# **ข้อ 21.** กำหนด `a = 12`, `b = 4` แล้วแสดงผลบวก ผลลบ ผลคูณ และผลหารของทั้งสอง

# %%
# ✍️ เขียนโค้ดข้อ 21 ที่นี่
a,b = 12,4

# %%
# ✅ ตรวจคำตอบข้อ 21 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(21)

# %% [markdown]
# **ข้อ 22.** กำหนดรัศมีวงกลม `r = 7` แล้วแสดงเส้นรอบวงและพื้นที่ (ใช้ 3.14159) ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 22 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 22 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(22)

# %% [markdown]
# **ข้อ 23.** กำหนด `n = 100` แล้วแสดงผลหารและเศษเมื่อหารด้วย 9 (ใช้ `//` และ `%`)

# %%
# ✍️ เขียนโค้ดข้อ 23 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 23 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(23)

# %% [markdown]
# **ข้อ 24.** กำหนดอุณหภูมิเซลเซียส `c = 30` แล้วแปลงเป็นฟาเรนไฮต์ (c×9/5+32) ทศนิยม 1 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 24 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 24 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(24)

# %% [markdown]
# **ข้อ 25.** กำหนดคะแนนสามวิชา `80, 75, 90` แล้วแสดงผลรวมและค่าเฉลี่ยทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 25 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 25 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(25)

# %% [markdown]
# **ข้อ 26.** กำหนดจำนวนเงิน `baht = 3500` แล้วแปลงเป็นดอลลาร์ (อัตรา 35 บาท/ดอลลาร์) ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 26 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 26 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(26)

# %% [markdown]
# **ข้อ 27.** กำหนดความกว้าง `w = 8` และความยาว `l = 5` ของสี่เหลี่ยม แล้วแสดงพื้นที่และเส้นรอบรูป

# %%
# ✍️ เขียนโค้ดข้อ 27 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 27 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(27)

# %% [markdown]
# **ข้อ 28.** กำหนดเลขจำนวนเต็มสามหลัก `n = 256` แล้วแสดงผลรวมของแต่ละหลัก

# %%
# ✍️ เขียนโค้ดข้อ 28 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 28 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(28)

# %% [markdown]
# **ข้อ 29.** กำหนดน้ำหนัก `w = 60` กก. และส่วนสูง `h = 1.70` เมตร แล้วคำนวณค่า BMI (w/h²) ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 29 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 29 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(29)

# %% [markdown]
# **ข้อ 30.** กำหนด `a = 3`, `b = 8` แล้วสลับค่าของทั้งสองโดยใช้การกำหนดค่าหลายตัวแปร จากนั้นแสดง `a`, `b`

# %%
# ✍️ เขียนโค้ดข้อ 30 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 30 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(30)

# %% [markdown]
# **ข้อ 31.** กำหนดราคาสินค้า `price = 500` และส่วนลด `discount = 20` (เปอร์เซ็นต์) แล้วแสดงราคาหลังหักส่วนลด

# %%
# ✍️ เขียนโค้ดข้อ 31 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 31 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(31)

# %% [markdown]
# **ข้อ 32.** กำหนด `sec = 200` วินาที แล้วแปลงเป็นรูปแบบ นาที:วินาที (เช่น 3:20)

# %%
# ✍️ เขียนโค้ดข้อ 32 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 32 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(32)

# %% [markdown]
# **ข้อ 33.** กำหนด `n = 6` แล้วแสดงค่ากำลังสองและกำลังสามของ `n`

# %%
# ✍️ เขียนโค้ดข้อ 33 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 33 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(33)

# %% [markdown]
# **ข้อ 34.** กำหนดเลขสองจำนวน `a = 15`, `b = 28` แล้วแสดงค่าเฉลี่ยทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 34 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 34 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(34)

# %% [markdown]
# **ข้อ 35.** กำหนดราคาสินค้า `price = 1500` แล้วคำนวณราคารวมที่มี VAT 7%

# %%
# ✍️ เขียนโค้ดข้อ 35 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 35 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(35)

# %% [markdown]
# **ข้อ 36.** กำหนด `minutes = 200` นาที แล้วแปลงเป็น ชั่วโมงและนาที

# %%
# ✍️ เขียนโค้ดข้อ 36 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 36 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(36)

# %% [markdown]
# **ข้อ 37.** กำหนดเลขจำนวนเต็ม `n = 12345` แล้วแสดงว่าหลักหน่วยคือเลขใด

# %%
# ✍️ เขียนโค้ดข้อ 37 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 37 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(37)

# %% [markdown]
# **ข้อ 38.** กำหนดระยะทาง `dist = 150` กม. และเวลา `time = 2.5` ชม. แล้วแสดงความเร็วเฉลี่ย (กม./ชม.)

# %%
# ✍️ เขียนโค้ดข้อ 38 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 38 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(38)

# %% [markdown]
# **ข้อ 39.** กำหนดเลขสี่หลัก `n = 1234` แล้วสลับหลักพันกับหลักหน่วย (1234 → 4231) โดยใช้ `//` และ `%`

# %%
# ✍️ เขียนโค้ดข้อ 39 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 39 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(39)

# %% [markdown]
# **ข้อ 40.** กำหนด `n = 8` แล้วแสดงผลของการบวกเลขนั้นกับตัวมันเอง 3 ครั้ง (n+n+n)

# %%
# ✍️ เขียนโค้ดข้อ 40 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 40 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(40)

# %% [markdown]
# ---
# ## ระดับที่ 3 — ท้าทาย (Challenge)
# _โจทย์ประยุกต์เชิงคณิตศาสตร์และตรรกะที่ต้องคิดวิเคราะห์_

# %% [markdown]
# **ข้อ 41.** กำหนดเลขจำนวนเต็มห้าหลัก `n = 54321` แล้วแสดงผลรวมของเลขทุกหลัก

# %%
# ✍️ เขียนโค้ดข้อ 41 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 41 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(41)

# %% [markdown]
# **ข้อ 42.** กำหนดยอดเงินกู้ `loan = 12000` และจำนวนเดือน `months = 6` แล้วแสดงยอดผ่อนต่อเดือน (ไม่คิดดอกเบี้ย)

# %%
# ✍️ เขียนโค้ดข้อ 42 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 42 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(42)

# %% [markdown]
# **ข้อ 43.** กำหนดด้านประกอบมุมฉากสองด้าน `a = 3`, `b = 4` แล้วแสดงด้านตรงข้ามมุมฉาก (√(a²+b²)) ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 43 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 43 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(43)

# %% [markdown]
# **ข้อ 44.** กำหนดจำนวนเงินรวม `money = 1250` แล้วแบ่งเป็นแบงก์ 100 ที่ใช้ได้มากที่สุด พร้อมเศษที่เหลือ

# %%
# ✍️ เขียนโค้ดข้อ 44 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 44 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(44)

# %% [markdown]
# **ข้อ 45.** กำหนดอุณหภูมิฟาเรนไฮต์ `f = 212` แล้วแปลงกลับเป็นเซลเซียส ((f−32)×5/9) ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 45 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 45 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(45)

# %% [markdown]
# **ข้อ 46.** กำหนดพิกัดจุดสองจุด `(1, 2)` และ `(4, 6)` แล้วคำนวณระยะห่างระหว่างจุด ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 46 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 46 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(46)

# %% [markdown]
# **ข้อ 47.** กำหนด `n = 4` แล้วคำนวณค่าพหุนาม 3n³ − 2n² + n − 7

# %%
# ✍️ เขียนโค้ดข้อ 47 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 47 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(47)

# %% [markdown]
# **ข้อ 48.** กำหนดราคาทุน `cost = 800` และราคาขาย `sell = 1000` แล้วคำนวณกำไรเป็นเปอร์เซ็นต์ของราคาทุน ทศนิยม 2 ตำแหน่ง

# %%
# ✍️ เขียนโค้ดข้อ 48 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 48 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(48)

# %% [markdown]
# **ข้อ 49.** กำหนดจำนวนวินาทีทั้งหมด `total = 3725` แล้วแปลงเป็นรูปแบบ ชั่วโมง:นาที:วินาที

# %%
# ✍️ เขียนโค้ดข้อ 49 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 49 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(49)

# %% [markdown]
# **ข้อ 50.** กำหนดเงินต้น `P = 10000`, อัตราดอกเบี้ยต่อปี `r = 5` (%) และจำนวนปี `t = 3` แล้วคำนวณดอกเบี้ยเชิงเดี่ยว (P×r×t/100)

# %%
# ✍️ เขียนโค้ดข้อ 50 ที่นี่

# %%
# ✅ ตรวจคำตอบข้อ 50 (รันหลังจากรันเซลล์คำตอบด้านบนแล้ว)
ตรวจ(50)
